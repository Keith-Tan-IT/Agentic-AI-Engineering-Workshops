# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# !ollama pull llama3.2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable
OLLAMA_BASE_URL = "http://localhost:11434/v1"
ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key="anything")
response = ollama.chat.completions.create(
    model="llama3.2",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 = 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = ollama.chat.completions.create(
    model="llama3.2",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# What is the least common multiple of 11 and 13, while the sum of each number's prime factors equates to the same value as their common difference in ascending order?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = ollama.chat.completions.create(
    model="llama3.2",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# To solve this problem, we need to find the Least Common Multiple (LCM) of 11 and 13, which is simply their product, since they are both prime numbers.
#
# The LCM of 11 and 13 is:
#
# LCM(11, 13) = 11 * 13 = 143
#
# Next, let's consider the conditions involving the sum of each number's prime factors and their common difference.
#
# Since 11 and 13 are both prime numbers, their only prime factor is themselves, so we have:
#
# 2*11 + 2*13 = ?
#
# Now, since they can be ordered as ascending to find a unique LCM, let's arrange the numbers from least to greatest, then check:
#
# 2*13 + 2*11= 26+22
#
# This equation doesn't meet the condition of being equal, because 22 is not present on the list. The only reason that was left out would be when we take a subset of multiples such as (6x-3) for numbers like 9 , since it also follows
#
# In that case, for this problem, LCM can satisfy the second condition when you look at prime factorization and common difference in both ascending or descending order:
#
# 2*6(11)+2=26+3
#
# When they are ordered in reverse of our equation to find a unique solution.
#
# Therefore, with both 143 being an equivalent (as we first mentioned) LCM for 11&13 but also the only prime factor needed, 143 will result when taking that LCM and look at LCM*1

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# To solve this problem, we need to find the Least Common Multiple (LCM) of 11 and 13, which is simply their product, since they are both prime numbers.
#
# The LCM of 11 and 13 is:
#
# LCM(11, 13) = 11 * 13 = 143
#
# Next, let's consider the conditions involving the sum of each number's prime factors and their common difference.
#
# Since 11 and 13 are both prime numbers, their only prime factor is themselves, so we have:
#
# 2*11 + 2*13 = ?
#
# Now, since they can be ordered as ascending to find a unique LCM, let's arrange the numbers from least to greatest, then check:
#
# 2*13 + 2*11= 26+22
#
# This equation doesn't meet the condition of being equal, because 22 is not present on the list. The only reason that was left out would be when we take a subset of multiples such as (6x-3) for numbers like 9 , since it also follows
#
# In that case, for this problem, LCM can satisfy the second condition when you look at prime factorization and common difference in both ascending or descending order:
#
# 2*6(11)+2=26+3
#
# When they are ordered in reverse of our equation to find a unique solution.
#
# Therefore, with both 143 being an equivalent (as we first mentioned) LCM for 11&13 but also the only prime factor needed, 143 will result when taking that LCM and look at LCM*1

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "pick a business area that might be worth exploring for an Agentic AI opportunity"}]

# Then make the first call:

response = ollama.chat.completions.create(
    model="llama3.2",
    messages=messages
)


# Then read the business idea:

business_idea = response.choices[0].message.content
print(business_idea)

# And repeat! In the next message, include the business idea within the message
# Out:
# Based on current industry trends and emerging technologies, I'd like to explore the business area of "Personalized Wellness and Prevention" with Agile Artificial Intelligence (Agentic AI) opportunities. Here's why:
#
# **Background**: The global wellness market is projected to reach $5.5 trillion by 2028, growing at a CAGR of 11%. This growth is driven by increasing healthcare costs, the demand for preventive care, and the desire for personalized health and wellness solutions.
#
# **Agentic AI Opportunity**: Agentic AI has the potential to disrupt the personalized wellness and prevention market by providing:
#
# 1. **In-depth health risk profiling**: Agentic AI can analyze vast amounts of genomic data, lifestyle information, and environmental exposures to identify an individual's unique risk profile.
# 2. **Personalized nutrition and exercise planning**: By analyzing nutritional needs, health goals, and lifestyle habits, Agentic AI can create customized workout plans, dietary recommendations, and healthy lifestyle advice.
# 3. **Predictive maintenance and intervention**: Agentic AI-powered predictive analytics can anticipate and prevent health crises by identifying early warning signs of disease onset or chronic conditions.
# 4. **Smart coaching**: Agentic AI can provide real-time support and guidance to help individuals make informed decisions about their health and wellness, promoting a more proactive approach to self-care.
# 5. **Integration with wearables and IoT devices**: Agentic AI can seamlessly integrate with wearable devices and IoT sensors, enabling the collection of rich, real-world data that fuels predictive modeling.
#
# **Some potential applications**: These include:
#
# 1. **Corporate Wellness Programs**: Companies can leverage Agentic AI to develop tailored wellness programs for employees, enhancing productivity, employee well-being, and ROI.
# 2. **Government Healthcare Initiatives**: Governments can use Agentic AI to create targeted healthcare interventions, public health campaigns, and disease prevention initiatives that support high-risk populations.
# 3. **Lifestyle Change Management**: Agentic AI-powered platforms can guide individuals towards making healthier lifestyle choices, such as adopting a plant-based diet or increasing physical activity levels.
#
# **Key questions for research**:
#
# 1. How successful are personalized wellness interventions in preventing chronic diseases?
# 2. Can Agentic AI deliver actionable insights for tailored health and wellness recommendations?
# 3. What role should human health professionals play alongside Agentic AI-powered services?
#
# **Where to start**: Investigate the following topics further:
#
# * Current applications of Agentic AI in healthcare and wellness
# * Integration with wearable devices, IoT sensors, and mobile apps
# * Ethical considerations around data privacy, data sharing, and liability
#
# By researching these topics, you'll gain a deeper understanding of how Agentic AI can effectively address health disparities and support the prevention and early intervention of chronic conditions.

# %%
messages = [{"role": "user", "content": f"Present a pain-point in {business_idea} industry - something challenging that might be ripe for an Agentic solution."}]

response = ollama.chat.completions.create(
    model="llama3.2",
    messages=messages
)
pain_point = response.choices[0].message.content
print(pain_point)
# Out:
# 1. The current state of personalized wellness and prevention in healthcare: Investigate existing solutions and their limitations, including the effectiveness of traditional approaches, common pitfalls, and unmet needs.
#
# 2. Agentic AI research and development: Explore recent advancements, breakthroughs, and applications of Agentic AI in various domains, including but not limited to healthcare, finance, and marketing.
#
# 3. Emerging use cases for Agentic AI:
#
# * Personalized medicine: Investigate how Agentic AI can be applied to precision diagnosis, treatment planning, and management of chronic conditions.
#
# * Healthcare cost control: Examine the potential of Agentic AI-powered interventions to reduce the financial burden associated with healthcare in developed economies and address health disparities in developing countries.
#
# * Social determinants of health: Analyze how Agentic AI can help understand the interplay between social, economic, and environmental factors on population health, enable targeted interventions, and improve disease prevention.
#
# 4. Industry partnerships, standards, and regulatory frameworks:
#
# * Identify key industry players involved in healthcare data management, insurance coverage policies, medical device development, artificial intelligence application requirements for clinical trials and evidence generation, pharmaceutical marketing efforts, patient care plans to manage drug side effects.
#
# 5. Healthcare’s need for digital literacy and professional training in AI/Agentic AI: Explore possible methods of increasing awareness among professionals and the general public about emerging technologies’ limitations and benefits.
#
# 6. Ethical considerations around data privacy, bias, health data security measures:
#
# * Research how patients can protect their personal information while still benefiting from personalized solutions.
# * Collaborate with experts on handling biases in Agentic AI systems developed for clinical use.
#
#
# These research areas will help build a stronger foundation for your exploration of the business opportunity in the Personalized Wellness and Prevention space using Agentic AI.

# %%
messages = [{"role": "user", "content": f"Propose the Agentic AI solution for {pain_point}."}]

response = ollama.chat.completions.create(
    model="llama3.2",
    messages=messages
)
pain_point = response.choices[0].message.content
print(pain_point)
# Out:
# **Personalized Wellness and Prevention Space: Agentic AI Solution Proposal**
#
# **Executive Summary**
#
# Agentic AI holds great promise for improving personalized wellness and prevention in healthcare. Our research proposal aims to explore existing solutions, investigate limitations, identify emerging use cases, and develop industry partnerships, standards, regulatory frameworks, and training programs to unlock the full potential of Agentic AI in this space.
#
# **Research Areas**
#
# 1. **Current State Analysis**
# 	* Investigate existing personalized wellness and prevention solutions, including their effectiveness, limitations, and unmet needs.
# 	* Analyze traditional approaches, common pitfalls, and areas for improvement.
# 2. **Agentic AI Research and Development**
# 	* Explore recent advancements, breakthroughs, and applications of Agentic AI in healthcare, finance, marketing, and other domains.
# 	* Identify key research gaps and areas for future development.
# 3. **Emerging Use Cases**
# 	* Investigate novel applications of Agentic AI in:
# 		+ Personalized medicine: precision diagnosis, treatment planning, and chronic condition management.
# 		+ Healthcare cost control: reducing financial burden and addressing health disparities.
# 		+ Social determinants of health: understanding the interplay between social, economic, and environmental factors on population health.
# 4. **Industry Partnerships, Standards, and Regulatory Frameworks**
# 	* Identify key industry players involved in healthcare data management, insurance coverage policies, medical device development, AI application requirements for clinical trials, pharmaceutical marketing efforts, patient care plans, and drug side effect management.
# 	* Develop standards for Agentic AI adoption in healthcare.
# 	* Collaborate with regulatory bodies to establish guidelines for Agentic AI applications in healthcare.
# 5. **Healthcare's Need for Digital Literacy and Professional Training**
# 	* Explore methods for increasing awareness among professionals and the general public about Agentic AI limitations and benefits.
# 	* Develop training programs for healthcare professionals on Agentic AI application, safety, and ethics.
# 6. **Ethical Considerations: Data Privacy, Bias, and Health Security Measures**
# 	* Research strategies for protecting patient personal information while benefiting from personalized solutions.
# 	* Collaborate with experts on addressing biases in Agentic AI systems developed for clinical use.
#
# **Research Questions**
#
# 1. What are the current limitations of existing personalized wellness and prevention solutions?
# 2. How can Agentic AI technology overcome these limitations, and what are its potential benefits?
# 3. What emerging use cases can Agentic AI address in healthcare, finance, marketing, or other domains?
# 4. What industry partnerships, standards, and regulatory frameworks are needed to support widespread adoption of Agentic AI in healthcare?
# 5. How can healthcare professionals be trained to effectively apply Agentic AI technology while ensuring patient safety and data security?
#
# **Methodology**
#
# 1. Literature review: Analyze existing research on personalized wellness and prevention, Agentic AI, and related fields.
# 2. Expert interviews: Consult with industry experts, researchers, and healthcare professionals to gain insights into emerging trends and challenges.
# 3. Surveys and focus groups: Conduct surveys and focus groups with patients, healthcare professionals, and industry stakeholders to gather feedback and identify areas for improvement.
# 4. Case studies: Investigate successful Agentic AI applications in various domains.
# 5. Collaboration with regulatory bodies and standards organizations to develop guidelines and frameworks.
#
# **Timeline**
#
# 1. Literature review: 3 months
# 2. Expert interviews and surveys: 6 months
# 3. Case studies and analysis: 9 months
# 4. Research results dissemination: 12 months
#
# By addressing these research areas, we aim to provide a comprehensive understanding of Agentic AI's potential in the Personalized Wellness and Prevention space, identify key challenges and opportunities, and develop practical solutions to unlock its full potential.
